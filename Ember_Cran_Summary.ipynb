# %%
#import R CRAN dependencies
C_di_up = read.csv("R_CRAN_direct_upstream_noV.summary",header = FALSE,sep = ';')
summary(C_di_up)
C_di_down = read.csv("R_CRAN_downstream_direct_noV.summary",header = FALSE,sep = ';')
summary(C_di_down)
C_re_up = read.csv("R_CRAN_upstream_recurs_noV.summary",header = FALSE,sep = ';')
summary(C_re_up)
C_re_down = read.csv("R_CRAN_downstream_recurs_noV.summary",header = FALSE,sep = ';')
summary(C_re_down)
# Out:
#             V1             V2
#  A3          :   1   Min.   :  1.000
#  ABC.RAP     :   1   1st Qu.:  2.000
#  ABCanalysis :   1   Median :  3.000
#  ABCoptim    :   1   Mean   :  5.112
#  ABCp2       :   1   3rd Qu.:  7.000
#  ABHgenotypeR:   1   Max.   :118.000
#  (Other)     :9959
#           V1             V2
#  AER       :   1   Min.   :   1.00
#  AGD       :   1   1st Qu.:   1.00
#  AICcmodavg:   1   Median :   2.00
#  AIM       :   1   Mean   :  12.64
#  APfun     :   1   3rd Qu.:   5.00
#  AUCRF     :   1   Max.   :1642.00
#  (Other)   :2709
#             V1             V2
#  A3          :   1   Min.   :  1.0
#  ABC.RAP     :   1   1st Qu.: 62.0
#  ABCanalysis :   1   Median :254.0
#  ABCoptim    :   1   Mean   :237.8
#  ABCp2       :   1   3rd Qu.:395.0
#  ABHgenotypeR:   1   Max.   :662.0
#  (Other)     :8032
#           V1             V2
#  AER       :   1   Min.   :   1.0
#  AGD       :   1   1st Qu.:   1.0
#  AICcmodavg:   1   Median :   3.0
# ...

# %%
#import R CRAN authorship network
C_au_net = read.csv("package2otherpackages.THRU.au.summary",header = FALSE,sep = ';')
summary(C_au_net)
C_ma_net = read.csv("package2otherpackages.THRU.ma.summary",header = FALSE,sep = ';')
summary(C_ma_net)
# Out:
#            V1             V2
#  A3         :   1   Min.   :  1.00
#  ABC.RAP    :   1   1st Qu.:  2.00
#  ABCanalysis:   1   Median :  4.00
#  ABCoptim   :   1   Mean   : 12.29
#  ACA        :   1   3rd Qu.: 11.00
#  ACD        :   1   Max.   :583.00
#  (Other)    :8580
#            V1             V2
#  ABCanalysis:   1   Min.   : 1.000
#  ABCoptim   :   1   1st Qu.: 1.000
#  ACD        :   1   Median : 3.000
#  ACDm       :   1   Mean   : 6.268
#  ACEt       :   1   3rd Qu.: 6.000
#  ACMEeqtl   :   1   Max.   :75.000
#  (Other)    :7195

# %%
#import Ember-Eco dependencies
E_di_up = read.csv("direct_upstream.summary",header = FALSE,sep = ';')
summary(E_di_up)
E_di_up_In = read.csv("direct_upstream.In.summary",header = FALSE,sep = ';')
summary(E_di_up_In)
E_di_up_Out = read.csv("direct_upstream.Out.summary",header = FALSE,sep = ';')
summary(E_di_up_Out)

E_di_down = read.csv("direct_downstream.summary",header = FALSE,sep = ';')
summary(E_di_down)
E_di_down_In = read.csv("direct_downstream.In.summary",header = FALSE,sep = ';')
summary(E_di_down_In)
E_di_down_Out = read.csv("direct_downstream.Out.summary",header = FALSE,sep = ';')
summary(E_di_down_Out)

E_re_up = read.csv("recursive_upstreams.summary",header = FALSE,sep = ';')
summary(E_re_up)
E_re_up_In = read.csv("recursive_upstreams.In.summary",header = FALSE,sep = ';')
summary(E_re_up_In)
E_re_up_Out = read.csv("recursive_upstreams.Out.summary",header = FALSE,sep = ';')
summary(E_re_up_Out)

E_re_down = read.csv("recursive_downstreams.summary",header = FALSE,sep = ';')
summary(E_re_down)
E_re_down_In = read.csv("recursive_downstreams.In.summary",header = FALSE,sep = ';')
summary(E_re_down_In)
E_re_down_Out = read.csv("recursive_downstreams.Out.summary",header = FALSE,sep = ';')
summary(E_re_down_Out)
# Out:
#                         V1             V2
#  @abcum/ember-appupdate  :   1   Min.   : 1.000
#  @abcum/ember-contextmenu:   1   1st Qu.: 1.000
#  @abcum/ember-domain     :   1   Median : 2.000
#  @abcum/ember-editables  :   1   Mean   : 3.171
#  @abcum/ember-gridlist   :   1   3rd Qu.: 4.000
#  @abcum/ember-helpers    :   1   Max.   :84.000
#  (Other)                 :2784
#                         V1             V2
#  @abcum/ember-appupdate  :   1   Min.   : 1.000
#  @abcum/ember-contextmenu:   1   1st Qu.: 1.000
#  @abcum/ember-domain     :   1   Median : 1.000
#  @abcum/ember-editables  :   1   Mean   : 1.916
#  @abcum/ember-gridlist   :   1   3rd Qu.: 2.000
#  @abcum/ember-helpers    :   1   Max.   :16.000
#  (Other)                 :2472
#                                V1             V2
#  @abcum/ember-editables         :   1   Min.   : 1.000
#  @abcum/ember-quill             :   1   1st Qu.: 1.000
#  @alexlafroscia/ember-wizard    :   1   Median : 2.000
# ...

# %%
#import Ember Eco authorship network
E_au_net = read.csv("ECOpackage2otherpackagesThuau.summary",header = FALSE,sep = ';')
summary(E_au_net)
E_ma_net = read.csv("ECOpackage2otherpackagesThuma.summary",header = FALSE,sep = ';')
summary(E_ma_net)
# Out:
#                                        V1            V2
#  authorization-ember-addon              :  1   Min.   : 1.000
#  babel-plugin-ember-modules-api-polyfill:  1   1st Qu.: 2.000
#  broccoli-ember-hbs-template-compiler   :  1   Median : 7.000
#  broccoli-ember-preparse                :  1   Mean   : 9.617
#  brunch-with-ember-and-bootstrap        :  1   3rd Qu.:15.000
#  bungle-ember                           :  1   Max.   :25.000
#  (Other)                                :600
#                                      V1             V2
#  affinity-engine-translator-ember-intl:   1   Min.   :  1.00
#  at-types-ember                       :   1   1st Qu.:  4.00
#  auth0-ember-simple-auth              :   1   Median : 14.00
#  authmaker-ember-simple-auth          :   1   Mean   : 16.82
#  authorization-ember-addon            :   1   3rd Qu.: 25.00
#  ax-ember                             :   1   Max.   :151.00
#  (Other)                              :2976

# %%
#box plot R CRAN dependency
boxplot(C_di_up[,2],C_di_down[,2],C_re_up[,2],C_re_down[,2],names = c('C_di_up','C_di_down','C_re_up','C_re_down'),main='R CRAN dependency')
boxplot(log(C_di_up[,2]+1),log(C_di_down[,2]+1),log(C_re_up[,2]+1),log(C_re_down[,2]+1),names = c('C_di_up','C_di_down','C_re_up','C_re_down'),main='R CRAN dependency log')
boxplot(C_di_up[,2],C_di_down[,2],C_re_up[,2],C_re_down[,2],log="y",names = c('C_di_up','C_di_down','C_re_up','C_re_down'),main='R CRAN dependency log scale of y')
# Out:
# Plot with title "R CRAN dependency"
# Plot with title "R CRAN dependency log"
# Plot with title "R CRAN dependency log scale of y"

# %%
#box plot R CRAN authorship network

boxplot(C_au_net[,2],C_ma_net[,2],names = c('C_au_net','C_ma_net'),main='R CRAN authorship network')
boxplot(log(C_au_net[,2]+1),log(C_ma_net[,2]+1),names = c('C_au_net','C_ma_net'),main='R CRAN authorship network log')
boxplot(C_au_net[,2],C_ma_net[,2],log="y",names = c('C_au_net','C_ma_net'),main='R CRAN authorship network log scale of y')
# Out:
# Plot with title "R CRAN authorship network"
# Plot with title "R CRAN authorship network log"
# Plot with title "R CRAN authorship network log scale of y"

# %%
#box plot Ember Eco dependency
boxplot(E_di_up[,2],E_di_down[,2],E_re_up[,2],E_re_down[,2],names = c('E_di_up','E_di_down','E_re_up','E_re_down'),main='Ember Eco dependency')
boxplot(log(E_di_up[,2]+1),log(E_di_down[,2]+1),log(E_re_up[,2]+1),log(E_re_down[,2]+1),names = c('E_di_up','E_di_down','E_re_up','E_re_down'),main='Ember Eco dependency log')
boxplot(E_di_up[,2],E_di_down[,2],E_re_up[,2],E_re_down[,2],log="y",names = c('E_di_up','E_di_down','E_re_up','E_re_down'),main='Ember Eco dependency log scale of y')
# Out:
# Plot with title "Ember Eco dependency"
# Plot with title "Ember Eco dependency log"
# Plot with title "Ember Eco dependency log scale of y"

# %%
#box plot Ember Eco dependency --IN & OUT
boxplot(E_di_up_In[,2],E_di_down_In[,2],E_di_up_Out[,2],E_di_down_Out[,2],E_re_up_In[,2],E_re_down_In[,2],E_re_up_Out[,2],E_re_down_Out[,2],names = c('E_di_up_In','E_di_down_In','E_di_up_Out','E_di_down_Out','E_re_up_In','E_re_down_In','E_re_up_Out','E_re_down_Out'),main='Ember Eco dependency IN & OUT')
boxplot(log(E_di_up_In[,2]+1),log(E_di_down_In[,2]+1),log(E_di_up_Out[,2]+1),log(E_di_down_Out[,2]+1),log(E_re_up_In[,2]+1),log(E_re_down_In[,2]+1),log(E_re_up_Out[,2]+1),log(E_re_down_Out[,2]+1),names = c('E_di_up_In','E_di_down_In','E_di_up_Out','E_di_down_Out','E_re_up_In','E_re_down_In','E_re_up_Out','E_re_down_Out'),main='Ember Eco dependency log IN & OUT')
boxplot(E_di_up_In[,2],E_di_down_In[,2],E_di_up_Out[,2],E_di_down_Out[,2],E_re_up_In[,2],E_re_down_In[,2],E_re_up_Out[,2],E_re_down_Out[,2],log="y",names = c('E_di_up_In','E_di_down_In','E_di_up_Out','E_di_down_Out','E_re_up_In','E_re_down_In','E_re_up_Out','E_re_down_Out'),main='Ember Eco dependency IN & OUT log scale of y')
# Out:
# Plot with title "Ember Eco dependency IN & OUT"
# Plot with title "Ember Eco dependency log IN & OUT"
# Plot with title "Ember Eco dependency IN & OUT log scale of y"

# %%
#box plot Ember Eco authorship network
boxplot(E_au_net[,2],E_ma_net[,2],names = c('E_au_net','E_ma_net'),main='Ember Eco authorship network')
boxplot(log(E_au_net[,2]+1),log(E_ma_net[,2]+1),names = c('E_au_net','E_ma_net'),main='Ember Eco authorship network log')
boxplot(E_au_net[,2],E_ma_net[,2],log="y",names = c('E_au_net','E_ma_net'),main='Ember Eco authorship network log of y')
# Out:
# Plot with title "Ember Eco authorship network"
# Plot with title "Ember Eco authorship network log"
# Plot with title "Ember Eco authorship network log of y"
